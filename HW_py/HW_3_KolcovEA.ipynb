# %% [markdown]
# **Задание 1**
#
# Дана переменная, в которой хранится словарь, содержащий гео-метки для каждого пользователя (пример структуры данных приведен ниже). Вам необходимо написать программу, которая выведет на экран множество уникальных гео-меток всех пользователей.
#
# Пример работы программы:
#
#
#
# ```
# ids = {'user1': [213, 213, 213, 15, 213],
#
#        'user2': [54, 54, 119, 119, 119],
#
#        'user3': [213, 98, 98, 35]}
# ```
#
#
#
# Результат: {98, 35, 15, 213, 54, 119}

# %%
ids = {'user1': [213, 213, 213, 15, 213],
       'user2': [54, 54, 119, 119, 119],
       'user3': [213, 98, 98, 35]}

uniq_geo = set()

for geo_values in ids.values():
  for geo in geo_values:
    uniq_geo.add(geo)

print(uniq_geo)
# Out:
# {98, 35, 15, 213, 54, 119}

# %% [markdown]
# ***Далее - решение препода:***
#
# в первой задаче можно было обойтись без вложенного цикла, если вспомнить, что и списки, и множества можно объединять не итерируясь по их элементам:

# %%
ids = {'user1': [213, 213, 213, 15, 213],
       'user2': [54, 54, 119, 119, 119],
       'user3': [213, 98, 98, 35]}

ids_set = set()                        # создаем множество

for id_ in ids.values():
    ids_set = ids_set.union(id_)      # .union() объединяет два множества ИЛИ  два списка
                                      #  объединили список (из значений словаря ids) и каждое перебранное значение-список из словаря в множество (дубликаты удалены автоматом)
print(ids_set)
# Out:
# {98, 35, 15, 213, 54, 119}

# %% [markdown]
# **Задание 2**
#
# Дана переменная, в которой хранится список поисковых запросов пользователя (пример структуры данных приведен ниже, но запросы потенциально могут быть любые). Вам необходимо написать программу, которая выведет на экран распределение количества слов в запросах в требуемом виде.
#
# Пример работы программы:
#
#
#
# ```
# queries = [
#     'смотреть сериалы онлайн',
#     'новости спорта',
#     'афиша кино',
#     'курс доллара',
#     'сериалы этим летом',
#     'курс по питону',
#     'сериалы про спорт',
# ]
# ```
#
#
# Результат:
#
# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%

# %%
queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт'
]


words_len = len(queries)            # длина списка - кол-во фраз = 100%
words_qty = set()                   # множество с разнообразием кол-ва слов

for phrase in queries:
  words_qty.add(len(phrase.split()))

phrase_dict = {}                   # словарь:      кол-во слов : кол-во фраз с таким кол-вом слов

for x in words_qty:
  n = 0
  for phrase in queries:
    if len(phrase.split()) == x:
      n += 1
      phrase_dict[x] = n

for key, value in phrase_dict.items():
  print(f'Поисковых запросов, содержащих {key} слов(а): {round(value/(words_len*0.01), 2)}%')
# Out:
# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%

# %% [markdown]
# ***Далее - решение препода:***
#
# вторую задачу я бы немного оптимизировал так при помощи list comprehension:

# %%
queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт'
]




for i in set([len(i.split()) for i in queries]):        # цикл в цикле - перебираем перебираемые элементы
                                                        # 1)     for i in set([len(i.split())  - то что выводим.
                                                        # 2)     for i in queries - перебираем каждый элемент списка и выводим то что написанао выше (там еще один перебор)
                                                        # в основном цикле перебираем i - каждую строку-элемент списка queries и в нем перебираем слова (слова получаем через split и помещаем длину строки в словах в set)
    print(f'Поисковых запросов, содержащих {i} слов(а): {len([s for s in queries if len(s.split()) == i ]) / len(queries) :.2%}')
                                                        # выводим i (кол-во слов, из множества), далее кол-во элементов из queries если кол-во слов == i (из множества)
                                                        # деленное на общее кол-во элементов queries и форматируем :.2%  (округление до двух знаков и %)
# Out:
# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%

# %% [markdown]
# **Задание 3**
#
# Дана переменная, в которой хранится информация о затратах и доходе рекламных кампаний по различным источникам. Необходимо дополнить исходную структуру показателем ROI, который рассчитаем по формуле: ((revenue / cost) - 1) * 100
#
# Пример работы программы:
#
#
# ```
# results = {
#     'vk': {'revenue': 103, 'cost': 98},
#     'yandex': {'revenue': 179, 'cost': 153},
#     'facebook': {'revenue': 103, 'cost': 110},
#     'adwords': {'revenue': 35, 'cost': 34},
#     'twitter': {'revenue': 11, 'cost': 24},
# }
# ```
#
#
#
# Результат:
#
#
#
# ```
# {'adwords': {'revenue': 35, 'cost': 34, 'ROI': 2.94},
#  'facebook': {'revenue': 103, 'cost': 110, 'ROI': -6.36},
#  'twitter': {'revenue': 11, 'cost': 24, 'ROI': -54.17},
#  'vk': {'revenue': 103, 'cost': 98, 'ROI': 5.1},
#  'yandex': {'revenue': 179, 'cost': 153, 'ROI': 16.99}}
# ```

# %%
results = {
    'vk': {'revenue': 103, 'cost': 98},
    'yandex': {'revenue': 179, 'cost': 153},
    'facebook': {'revenue': 103, 'cost': 110},
    'adwords': {'revenue': 35, 'cost': 34},
    'twitter': {'revenue': 11, 'cost': 24},
}


for key in results.keys():
  revenue = results[key]['revenue']
  cost = results[key]['cost']
  roi = round(((revenue / cost) - 1) * 100, 2)
  results[key] = {'revenue' : revenue, 'cost' : cost, 'ROI' : roi}

print(results)
# Out:
# {'vk': {'revenue': 103, 'cost': 98, 'ROI': 5.1}, 'yandex': {'revenue': 179, 'cost': 153, 'ROI': 16.99}, 'facebook': {'revenue': 103, 'cost': 110, 'ROI': -6.36}, 'adwords': {'revenue': 35, 'cost': 34, 'ROI': 2.94}, 'twitter': {'revenue': 11, 'cost': 24, 'ROI': -54.17}}

# %% [markdown]
# **Задание 4**
#
# Дана переменная, в которой хранится статистика рекламных каналов по объемам продаж (пример структуры данных приведен ниже). Напишите программу, которая возвращает название канала с максимальным объемом продаж.
#
# Пример работы программы:
#
#
# ```
# stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}
# ```
#
#
#
# Результат:
#
# Максимальный объем продаж на рекламном канале: vk

# %%
stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}

sales = 0
place = ''

for key, value in stats.items():
  if value > sales:
    sales = value
    place  = key

print(f'Максимальный объем продаж на рекламном канале: {place}')
# Out:
# Максимальный объем продаж на рекламном канале: vk

# %% [markdown]
# ***Далее - решение препода:***
#
# у 4 задачи есть еще много разных способов решения, если будет интересно, изучите вот этот:
#
# Для поиска в Python-словаре ключа с максимальным значением можно использовать функцию max()
#
# Функция max() перебирает все ключи k в словаре stats и после применения метода stats.get(k) выбирает тот, что имеет максимальное значение. При этом метод get() возвращает значение, соответствующее ключу k в словаре stats.

# %%
stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}

print(max(stats, key=stats.get))    # max() перебирает и сравнивает все элементы , ЕСЛИ словарь перебираем, то получаем методом get ключи и значения
# Out:
# vk

# %% [markdown]
# **Задание 5 (необязательно)**
#
# Дан список произвольной длины. Необходимо написать код, который на основе исходного списка составит словарь такого уровня вложенности, какова длина исхондого списка.
#
# Примеры работы программы:
#
#
# ```
# my_list = ['2018-01-01', 'yandex', 'cpc', 100]
# ```
#
# Результат:
#
#  {'2018-01-01': {'yandex': {'cpc': 100}}}
#
#
# ```
# my_list = ['a', 'b', 'c', 'd', 'e', 'f']
# ```
#
# Результат:
#
#  {'a': {'b': {'c': {'d': {'e': 'f'}}}}}

# %%
my_list1 = ['2018-01-01', 'yandex', 'cpc', 100]
my_list2 = ['a', 'b', 'c', 'd', 'e', 'f']


def dict_in_dict(my_list):
  my_dict = {}                    # итоговый словарь
  last = my_list[-1]              # значение начального словаря
  pre_last = my_list[-2]          # ключ начального словаря
  my_dict[pre_last] = last        # начальный словарь

  if len(my_list) > 2:
    for n in reversed(range(0, len(my_list)-2)):       # перебор списка в обратном порядке (кроме последних двух элементов)
        my_dict_copy = my_dict.copy()                  # копирование последнего состояния итогового словаря
        my_dict.clear()                                # очистка итогового словаря
        my_dict[my_list[n]] = my_dict_copy             # перезапись итогового словаря

  print(my_dict)



dict_in_dict(my_list1)
dict_in_dict(my_list2)
# Out:
# {'2018-01-01': {'yandex': {'cpc': 100}}}
# {'a': {'b': {'c': {'d': {'e': 'f'}}}}}

# %% [markdown]
# **Задание 6 (необязательно)**
#
# Дана книга рецептов с информацией о том, сколько ингредиентов нужно для приготовления блюда в расчете на одну порцию (пример данных представлен ниже).
# Напишите программу, которая будет запрашивать у пользователя количество порций для приготовления этих блюд и отображать информацию о суммарном количестве требуемых ингредиентов в указанном виде.
# Внимание! Одинаковые ингредиенты с разными размерностями нужно считать раздельно!
# Пример работы программы:
#
#
#
# ```
# cook_book = {
#   'салат': [
#      {'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
#      {'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
#      {'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
#      {'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
#      {'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
#      {'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
#      {'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
#     ],
#   'пицца': [
#      {'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
#      {'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
#      {'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
#      {'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
#      {'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
#      {'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},
#     ],
#   'лимонад': [
#      {'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
#      {'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
#      {'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
#      {'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},
#     ]
# }
#
# ```
#
# Введите количество порций:
#
# 3
#
# Результат:
#
# ```
# Сыр: 210 гр
# Томаты: 6 шт
# Огурцы: 60 гр
# Маслины: 30 гр
# Оливковое масло: 60 мл
# Салат: 30 гр
# Перец: 60 гр
# Колбаса: 90 гр
# Бекон: 90 гр
# Оливки: 30 гр
# Томаты: 60 гр
# Тесто: 300 гр
# Лимон: 3 шт
# Вода: 600 мл
# Сахар: 30 гр
# Лайм: 60 гр
# ```

# %%
cook_book = {
  'салат': [
     {'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
     {'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
     {'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
    ],
  'пицца': [
     {'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},
    ],
  'лимонад': [
     {'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
     {'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
     {'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},
    ]
}


ingridient = []                    # списки ингридиентов, кол-ва, ед. изм. ..
quantity = []
measure = []
new_ingridient = []                # модифицированные списки (без повторов)..
new_quantity = []
new_measure = []

for value in cook_book.values():          # извлекаем значения (внутр. словари)
    for dict in value:
      ingridient.append(dict['ingridient_name'])  # распределяем по спискам..
      quantity.append(dict['quantity'])
      measure.append(dict['measure'])

while n < len(ingridient):
    ingridient_value = ingridient.pop(n)      # копируем в переменную и удаляем перебираемый элемент..
    quantity_value = quantity.pop(n)
    measure_value = measure.pop(n)

    if ingridient_value in ingridient:                   # если находится повтор,
      index = ingridient.index(ingridient_value)         # выясняем индекс повтора
      ingridient.pop(index)                              # удаляем повтор
      quantity_value = quantity_value + quantity[index]  # складываем кол-во, ориентируемся на выявленный индекс
      quantity.pop(index)                                # удаляем элемент, ориентируясь на выявленный индекс ..
      measure.pop(index)

    # добавляем обновленные данные в новые списки
    new_ingridient.append(ingridient_value)             # наполняем модифицированные списки (без повторов)..
    new_quantity.append(quantity_value)
    new_measure.append(measure_value)

a = int(input('Ввод количества порций: '))

for m in range(0, len(new_ingridient)):
  print(f'{new_ingridient[m].capitalize()}: {new_quantity[m] * a} {new_measure[m]}')   # выводим данные, учитывая введенное кол-во порций
# Out:
# Ввод количества порций: 3
# Сыр: 210 гр
# Томаты: 66 шт
# Огурцы: 60 гр
# Маслины: 30 гр
# Оливковое масло: 60 мл
# Салат: 30 гр
# Перец: 60 гр
# Колбаса: 90 гр
# Бекон: 90 гр
# Оливки: 30 гр
# Тесто: 300 гр
# Лимон: 3 шт
# Вода: 600 мл
# Сахар: 30 гр
# Лайм: 60 гр

# %% [markdown]
# ***Далее - решение препода:***
#
# а 6 задачу можно оптимизировать вот таким хитрым способом:

# %%
cook_book = {
  'салат': [
     {'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
     {'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
     {'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
    ],
  'пицца': [
     {'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},
    ],
  'лимонад': [
     {'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
     {'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
     {'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},
    ]
}


numb_servings = int(input('Укажите количество порций: '))
quantity_book = {}

for ingred_book in sum(cook_book.values(), []):
  ingred_key = (ingred_book['ingridient_name'], ingred_book['measure'])                       # ('сыр', 'гр')
  quantity_book[ingred_key] = quantity_book.get(ingred_key, 0) + ingred_book['quantity']      # 50   2   20  10   ...
                                                                                              # .get(keyname, value)  ключ, значение по умолчанию (если нет его)

for (ingred_name, measure), quantity in quantity_book.items():
  print(f'{ingred_name.capitalize()}: {quantity * numb_servings} {measure}')
# Out:
# Укажите количество порций: 3
# Сыр: 210 гр
# Томаты: 6 шт
# Огурцы: 60 гр
# Маслины: 30 гр
# Оливковое масло: 60 мл
# Салат: 30 гр
# Перец: 60 гр
# Колбаса: 90 гр
# Бекон: 90 гр
# Оливки: 30 гр
# Томаты: 60 гр
# Тесто: 300 гр
# Лимон: 3 шт
# Вода: 600 мл
# Сахар: 30 гр
# Лайм: 60 гр
